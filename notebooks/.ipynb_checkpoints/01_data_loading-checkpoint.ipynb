# %% [markdown]
# # 1. Data Loading & Exploration
# Load the education dataset and understand its structure.

# %%
import pandas as pd
import sys
sys.path.append('../scripts')
from helpers import load_education_data, get_data_summary

# Load the data
df = load_education_data('../data/khi_education_demo.csv')
print("Data loaded successfully!")
print(f"Shape: {df.shape}")

# %%
# View first few rows
df.head(10)

# %%
# Get data types and info
df.info()

# %%
# Summary statistics
get_data_summary(df)

# %%
# Check for missing values
print("Missing values:")
print(df.isnull().sum())

# %%
# Basic statistics
df.describe()
