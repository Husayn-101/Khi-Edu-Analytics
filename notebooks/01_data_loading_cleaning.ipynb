# %% [markdown]
# # 01 - Data Loading & Exploration
#
# Load the Karachi Education Survey data and explore its structure.

# %%
import sys
sys.path.insert(0, '../scripts')
from helpers import *
import pandas as pd
import numpy as np

# %%
# Load the survey data
df = load_survey_data()
print(f"Data loaded: {df.shape[0]} responses")
print(f"\nColumn names:")
print(df.columns.tolist())
# Out:
# Data loaded: 34 responses
#
# Column names:
# ['Timestamp', 'Age', 'Grade/Class', 'Gender', 'Average hours spent studying per day', 'Preferred study method', 'Subject(s) you find most challenging', 'Extra-curricular activities you participate in', 'Do you feel marginalized or discriminated against at School/College/University?', 'Have you ever used tobacco, alcohol, or other substances?']

# %%
# Display first few rows
df.head()
# Out:
#                      Timestamp  Age             Grade/Class  Gender  \
# 0  2026/03/28 6:00:05 AM GMT+5   20  Under-Grad (Bachelors)  Female
# 1  2026/03/28 6:07:50 AM GMT+5   16                      11    Male
# 2  2026/03/28 6:21:00 AM GMT+5   17                      10    Male
# 3  2026/03/28 6:30:41 AM GMT+5   28     Post-grad (Masters)  Female
# 4  2026/03/28 6:34:17 AM GMT+5   18                      12    Male
#
#   Average hours spent studying per day  \
# 0                     Less than 1 hour
# 1                            1–2 hours
# 2                     Less than 1 hour
# 3                            2–4 hours
# 4                            1–2 hours
#
#                          Preferred study method  \
# 0                                    Self-study
# 1  Self-study;Online tutorials;Coaching classes
# 2                   Self-study;Online tutorials
# 3                   Self-study;Online tutorials
# 4                   Self-study;Coaching classes
#
# ...

# %%
# Data info and missing values
print("Data Info:")
print(df.info())
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Data Info:
# <class 'pandas.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 10 columns):
#  #   Column                                                                           Non-Null Count  Dtype
# ---  ------                                                                           --------------  -----
#  0   Timestamp                                                                        34 non-null     str
#  1   Age                                                                              34 non-null     int64
#  2   Grade/Class                                                                      34 non-null     str
#  3   Gender                                                                           34 non-null     str
#  4   Average hours spent studying per day                                             34 non-null     str
#  5   Preferred study method                                                           34 non-null     str
# ...

# %%
# Clean the data
df_clean = clean_survey_data(df)
print("Data cleaned successfully")
print(f"\nCleaned columns:")
print(df_clean.columns.tolist())
# Out:
# Data cleaned successfully
#
# Cleaned columns:
# ['timestamp', 'age', 'grade/class', 'gender', 'average_hours_spent_studying_per_day', 'preferred_study_method', 'subject(s)_you_find_most_challenging', 'extra-curricular_activities_you_participate_in', 'do_you_feel_marginalized_or_discriminated_against_at_school/college/university?', 'have_you_ever_used_tobacco,_alcohol,_or_other_substances?']

# %%
# Basic statistics
print(df_clean.describe())
# Out:
#       timestamp        age
# count         0  34.000000
# mean        NaT  19.147059
# min         NaT  15.000000
# 25%         NaT  17.000000
# 50%         NaT  17.000000
# 75%         NaT  19.750000
# max         NaT  48.000000
# std         NaN   5.888522

# %%
# Display summary
get_data_summary(df_clean)
# Out:
# Dataset Shape: (34, 10)
# Columns: ['timestamp', 'age', 'grade/class', 'gender', 'average_hours_spent_studying_per_day', 'preferred_study_method', 'subject(s)_you_find_most_challenging', 'extra-curricular_activities_you_participate_in', 'do_you_feel_marginalized_or_discriminated_against_at_school/college/university?', 'have_you_ever_used_tobacco,_alcohol,_or_other_substances?']
# Missing Values:
# timestamp                                                                          34
# age                                                                                 0
# grade/class                                                                         0
# gender                                                                              0
# average_hours_spent_studying_per_day                                                0
# preferred_study_method                                                              0
# ...
